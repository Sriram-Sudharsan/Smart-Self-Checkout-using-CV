# %% [markdown]
# <a href="https://colab.research.google.com/github/Sriram-Sudharsan/Smart-Self-Checkout-using-CV/blob/main/TCS_IC_Retail_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image classification - TCS Internship

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pathlib
data = pathlib.Path('/content/gdrive/MyDrive/Dataset/TCS_Data_Augmented')
#Identifying number of images belonging to the three formats 
count = len(list(data.glob('*/*.png')))
count1 = len(list(data.glob('*/*.jpg')))
count2 = len(list(data.glob('*/*.jpeg')))
#Note currently searched only .png format images


count+count1+count2
# Out:
# 288

# %%
#Creating a list and adding the images of Item Name: Glucon_D,Atta,Maaza,Maggi and Oreo
import PIL 

Glucon = list(data.glob('Glucon_D/*'))
Atta = list(data.glob('Atta/*'))
Hide_Seek = list(data.glob('Hide_Seek/*'))
Maaza = list(data.glob('Maaza/*'))
Maggi = list(data.glob('Maggi/*'))
Oreo = list(data.glob('Oreo/*'))
print("Oreo")
print(len(Oreo))
print("Maaza")
print(len(Maaza))
print("Hide&Seek")
print(len(Hide_Seek))
print("Glucon_D")
print(len(Glucon))
print("Atta")
print(len(Atta))
# Out:
# Oreo
# 48
# Maaza
# 48
# Hide&Seek
# 48
# Glucon_D
# 48
# Atta
# 49

# %%
 batch_size = 10
img_height = 530
img_width = 530

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data,
  validation_split=0.1, #Doing 90-10 train-valid split as suggested
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 288 files belonging to 6 classes.
# Using 260 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data,
  validation_split=0.1, #Doing 90-10 train-valid split as suggested
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 288 files belonging to 6 classes.
# Using 28 files for validation.

# %%
#Identifying types of classes
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Atta', 'Glucon_D', 'Hide_Seek', 'Maaza', 'Maggi', 'Oreo']

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (10, 530, 530, 3)
# (10,)

# %%
#Note-self: AUTOTUNE tunes value dynamically
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %%
#Noteself: Normalizing values between 0 and 1
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]

print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
num_classes = 6
#'Atta', 'Glucon_D', 'Hide_Seek', 'Maaza', 'Maggi', 'Oreo'


model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_1 (Rescaling)      (None, 530, 530, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 530, 530, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 265, 265, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 265, 265, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 132, 132, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 132, 132, 64)      18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 66, 66, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 278784)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               35684480
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 35,708,838
# Trainable params: 35,708,838
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 26/26 [==============================] - 41s 457ms/step - loss: 3.5367 - accuracy: 0.3923 - val_loss: 0.5413 - val_accuracy: 0.8571
# Epoch 2/10
# 26/26 [==============================] - 3s 113ms/step - loss: 0.3379 - accuracy: 0.8923 - val_loss: 0.1075 - val_accuracy: 1.0000
# Epoch 3/10
# 26/26 [==============================] - 3s 112ms/step - loss: 0.1541 - accuracy: 0.9500 - val_loss: 0.0411 - val_accuracy: 0.9643
# Epoch 4/10
# 26/26 [==============================] - 3s 113ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 5/10
# 26/26 [==============================] - 3s 112ms/step - loss: 4.5835e-04 - accuracy: 1.0000 - val_loss: 4.1117e-04 - val_accuracy: 1.0000
# Epoch 6/10
# 26/26 [==============================] - 3s 112ms/step - loss: 2.2309e-04 - accuracy: 1.0000 - val_loss: 2.3977e-04 - val_accuracy: 1.0000
# Epoch 7/10
# 26/26 [==============================] - 3s 113ms/step - loss: 1.3743e-04 - accuracy: 1.0000 - val_loss: 1.9036e-04 - val_accuracy: 1.0000
# Epoch 8/10
# 26/26 [==============================] - 3s 112ms/step - loss: 9.9893e-05 - accuracy: 1.0000 - val_loss: 1.4095e-04 - val_accuracy: 1.0000
# Epoch 9/10
# 26/26 [==============================] - 3s 112ms/step - loss: 6.9032e-05 - accuracy: 1.0000 - val_loss: 6.5326e-05 - val_accuracy: 1.0000
# Epoch 10/10
# 26/26 [==============================] - 3s 113ms/step - loss: 4.7569e-05 - accuracy: 1.0000 - val_loss: 7.5301e-05 - val_accuracy: 1.0000

# %%
  acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.6), #Note to Self: changed parameters
    layers.experimental.preprocessing.RandomZoom(0.6),
    layers.experimental.preprocessing.RandomTranslation(height_factor=0.2, width_factor=0.2, fill_mode="wrap"),
    #layers.experimental.preprocessing.RandomContrast(0.1)
    layers.experimental.preprocessing.RandomCrop(250,250)


    #Note to Self: Changed Parameters
  ]
)


plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),

  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(32, activation='relu'),
  layers.Dense(num_classes,activation='softmax')
])
# Note to self: relu: Rectified Linear Unit-Activation Fn#
# Note to self: Dropout takes a fractional number as its input value, in the form such as 0.1, 0.2, 0.4, etc. 
#This means dropping out 10%, 20% or 40% of the output units randomly from the applied layer.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.summary()
#Note to self: Optimizers are algorithms or methods used to change 
#the attributes of the neural network such as weights and learning rate to reduce the losses.
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_1 (Sequential)    (None, 250, 250, 3)       0
# _________________________________________________________________
# rescaling_2 (Rescaling)      (None, 250, 250, 3)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 250, 250, 16)      448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 125, 125, 16)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 125, 125, 32)      4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 62, 62, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 62, 62, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 123008)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                3936288
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 3,941,574
# Trainable params: 3,941,574
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 60
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/60
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/backend.py:4930: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`sparse_categorical_crossentropy` received `from_logits=True`, but '
# 26/26 [==============================] - 3s 58ms/step - loss: 2.8091 - accuracy: 0.3115 - val_loss: 1.4225 - val_accuracy: 0.3571
# Epoch 2/60
# 26/26 [==============================] - 1s 47ms/step - loss: 1.1761 - accuracy: 0.5346 - val_loss: 0.9390 - val_accuracy: 0.5714
# Epoch 3/60
# 26/26 [==============================] - 1s 48ms/step - loss: 0.8452 - accuracy: 0.6538 - val_loss: 0.6345 - val_accuracy: 0.8929
# Epoch 4/60
# 26/26 [==============================] - 1s 46ms/step - loss: 0.5740 - accuracy: 0.8038 - val_loss: 0.4040 - val_accuracy: 0.8929
# Epoch 5/60
# 26/26 [==============================] - 1s 52ms/step - loss: 0.4986 - accuracy: 0.8000 - val_loss: 0.2154 - val_accuracy: 1.0000
# Epoch 6/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.3543 - accuracy: 0.9000 - val_loss: 0.4318 - val_accuracy: 0.7857
# Epoch 7/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.2806 - accuracy: 0.9000 - val_loss: 0.1766 - val_accuracy: 0.9643
# Epoch 8/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.4641 - accuracy: 0.8423 - val_loss: 0.5293 - val_accuracy: 0.9286
# Epoch 9/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.5122 - accuracy: 0.8192 - val_loss: 0.1797 - val_accuracy: 1.0000
# Epoch 10/60
# 26/26 [==============================] - 1s 46ms/step - loss: 0.3699 - accuracy: 0.8808 - val_loss: 0.6187 - val_accuracy: 0.7857
# Epoch 11/60
# 26/26 [==============================] - 1s 48ms/step - loss: 0.3052 - accuracy: 0.8962 - val_loss: 0.1903 - val_accuracy: 0.9286
# Epoch 12/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.2829 - accuracy: 0.9038 - val_loss: 0.2547 - val_accuracy: 0.8571
# Epoch 13/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1781 - accuracy: 0.9500 - val_loss: 0.2332 - val_accuracy: 0.8571
# Epoch 14/60
# 26/26 [==============================] - 1s 46ms/step - loss: 0.2241 - accuracy: 0.9308 - val_loss: 0.3336 - val_accuracy: 0.8214
# Epoch 15/60
# 26/26 [==============================] - 1s 53ms/step - loss: 0.2085 - accuracy: 0.9346 - val_loss: 0.1269 - val_accuracy: 0.9286
# Epoch 16/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1969 - accuracy: 0.9308 - val_loss: 0.3767 - val_accuracy: 0.8571
# Epoch 17/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1740 - accuracy: 0.9385 - val_loss: 0.5472 - val_accuracy: 0.8214
# Epoch 18/60
# 26/26 [==============================] - 1s 46ms/step - loss: 0.1664 - accuracy: 0.9385 - val_loss: 0.0517 - val_accuracy: 1.0000
# Epoch 19/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.2065 - accuracy: 0.9538 - val_loss: 0.6574 - val_accuracy: 0.8214
# Epoch 20/60
# 26/26 [==============================] - 1s 46ms/step - loss: 0.1918 - accuracy: 0.9423 - val_loss: 0.1445 - val_accuracy: 0.9286
# Epoch 21/60
# 26/26 [==============================] - 1s 46ms/step - loss: 0.2014 - accuracy: 0.9231 - val_loss: 0.1072 - val_accuracy: 0.9643
# Epoch 22/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1341 - accuracy: 0.9538 - val_loss: 0.0342 - val_accuracy: 1.0000
# Epoch 23/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1067 - accuracy: 0.9692 - val_loss: 0.0282 - val_accuracy: 1.0000
# Epoch 24/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1443 - accuracy: 0.9308 - val_loss: 0.2005 - val_accuracy: 0.8929
# Epoch 25/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1322 - accuracy: 0.9462 - val_loss: 0.0251 - val_accuracy: 1.0000
# Epoch 26/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1316 - accuracy: 0.9577 - val_loss: 0.0627 - val_accuracy: 1.0000
# Epoch 27/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.2129 - accuracy: 0.9231 - val_loss: 0.5945 - val_accuracy: 0.8214
# Epoch 28/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.2595 - accuracy: 0.9154 - val_loss: 0.1823 - val_accuracy: 0.9286
# Epoch 29/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.3674 - accuracy: 0.9154 - val_loss: 0.1617 - val_accuracy: 0.9643
# Epoch 30/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1690 - accuracy: 0.9500 - val_loss: 0.2427 - val_accuracy: 0.8214
# Epoch 31/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1725 - accuracy: 0.9346 - val_loss: 0.1158 - val_accuracy: 0.9643
# Epoch 32/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1170 - accuracy: 0.9577 - val_loss: 0.0949 - val_accuracy: 0.9643
# Epoch 33/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1257 - accuracy: 0.9615 - val_loss: 0.2263 - val_accuracy: 0.8929
# Epoch 34/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1099 - accuracy: 0.9731 - val_loss: 0.1306 - val_accuracy: 0.9643
# Epoch 35/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1712 - accuracy: 0.9423 - val_loss: 0.3092 - val_accuracy: 0.8214
# Epoch 36/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1556 - accuracy: 0.9385 - val_loss: 0.1473 - val_accuracy: 0.9286
# Epoch 37/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.2681 - accuracy: 0.9077 - val_loss: 0.1684 - val_accuracy: 0.9643
# Epoch 38/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1882 - accuracy: 0.9346 - val_loss: 0.1365 - val_accuracy: 0.9643
# Epoch 39/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1540 - accuracy: 0.9462 - val_loss: 0.1509 - val_accuracy: 0.9286
# Epoch 40/60
# 26/26 [==============================] - 1s 48ms/step - loss: 0.1518 - accuracy: 0.9500 - val_loss: 0.2533 - val_accuracy: 0.8214
# Epoch 41/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1229 - accuracy: 0.9500 - val_loss: 0.0759 - val_accuracy: 1.0000
# Epoch 42/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1304 - accuracy: 0.9538 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 43/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1095 - accuracy: 0.9615 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 44/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1128 - accuracy: 0.9615 - val_loss: 0.0249 - val_accuracy: 1.0000
# Epoch 45/60
# 26/26 [==============================] - 1s 48ms/step - loss: 0.1355 - accuracy: 0.9615 - val_loss: 0.0221 - val_accuracy: 1.0000
# Epoch 46/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1136 - accuracy: 0.9538 - val_loss: 0.0998 - val_accuracy: 1.0000
# Epoch 47/60
# 26/26 [==============================] - 1s 48ms/step - loss: 0.1439 - accuracy: 0.9500 - val_loss: 0.0852 - val_accuracy: 1.0000
# Epoch 48/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1496 - accuracy: 0.9462 - val_loss: 0.0298 - val_accuracy: 1.0000
# Epoch 49/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.0774 - accuracy: 0.9731 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 50/60
# 26/26 [==============================] - 1s 48ms/step - loss: 0.1891 - accuracy: 0.9231 - val_loss: 0.4893 - val_accuracy: 0.7857
# Epoch 51/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1603 - accuracy: 0.9423 - val_loss: 0.0177 - val_accuracy: 1.0000
# Epoch 52/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1049 - accuracy: 0.9577 - val_loss: 0.0273 - val_accuracy: 1.0000
# Epoch 53/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1644 - accuracy: 0.9231 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 54/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1006 - accuracy: 0.9731 - val_loss: 0.0664 - val_accuracy: 0.9643
# Epoch 55/60
# 26/26 [==============================] - 1s 48ms/step - loss: 0.1167 - accuracy: 0.9692 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 56/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1004 - accuracy: 0.9577 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 57/60
# 26/26 [==============================] - 1s 48ms/step - loss: 0.1427 - accuracy: 0.9538 - val_loss: 0.1207 - val_accuracy: 0.8929
# Epoch 58/60
# 26/26 [==============================] - 1s 47ms/step - loss: 0.1501 - accuracy: 0.9577 - val_loss: 0.1086 - val_accuracy: 0.9286
# Epoch 59/60
# 26/26 [==============================] - 1s 48ms/step - loss: 0.4189 - accuracy: 0.9115 - val_loss: 0.0226 - val_accuracy: 1.0000
# Epoch 60/60
# 26/26 [==============================] - 1s 48ms/step - loss: 0.2382 - accuracy: 0.9308 - val_loss: 0.0215 - val_accuracy: 1.0000

# %%
  acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# !pip install pyyaml h5py
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (3.1.0)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py) (1.5.2)
# Requirement already satisfied: numpy>=1.14.5; python_version == "3.7" in /usr/local/lib/python3.7/dist-packages (from h5py) (1.19.5)

# %%
tf.keras.models.save_model(model,'my_model2.hdf5')

# %%
import pickle
from sklearn.externals import joblib
file_dir = 'Mymodelnew1.h5'
model.save(file_dir)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
import pathlib
data1 = pathlib.Path('/content/gdrive/MyDrive/Dataset/Test') 
#check whether the image count is correct- Have 3 images in test folder. 2 Oreo and 1 Glucon D
count2 = len(list(data1.glob('*.jpeg')))


count2
# Out:
# 4

# %%
from tensorflow.keras.models import load_model
img = keras.preprocessing.image.load_img('/content/gdrive/MyDrive/Dataset/Test/1.jpg', target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
modelsaved = "Mymodelnew1.h5"
model1 = load_model(modelsaved)

predictions = model1.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image is {} "
    .format(class_names[np.argmax(score)])
)
#Note the above image have not been seen by the model. The image has a picture of a Oreo packet randomly downloaded from the web for the testing purpose
# Out:
# This image is Maggi

# %%
img = keras.preprocessing.image.load_img('/content/gdrive/MyDrive/Dataset/Test/oreo-biscuit-packet-hand-98504457.jpg', target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image is {} "
    .format(class_names[np.argmax(score)])
)
#Note the above image have not been seen by the model. The image has a picture of a gluconD packet(Orange)
# Out:
# This image is Oreo

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model1.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model1.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from keras.models import model_from_json
# load json and create model
json_file = open('model1.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model1.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
img = keras.preprocessing.image.load_img('/content/gdrive/MyDrive/Dataset/Test/1.jpg', target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = loaded_model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image is {} "
    .format(class_names[np.argmax(score)])
)
#Note the above image have not been seen by the model. The image has a picture of a gluconD packet(Orange)
# Out:
# This image is Maggi
